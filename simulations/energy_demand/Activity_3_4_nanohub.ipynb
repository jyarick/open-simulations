# %% [markdown]
# <div style="margin:25px 0; border-radius:6px; overflow:hidden;">
#   <div style="height:10px; background:linear-gradient(to right,
#     #D64541,
#     #F39C12,
#     #F1C40F,
#     #27AE60,
#     #16A085,
#     #2980B9,
#     #8E44AD
#   );"></div>
# </div>

# %% [markdown]
# # <font color="#1E7F3F">PTCHS: Activity 3 & 4 Notebook</font>
# ### <font color="#9BBF9A">Author: <b>Jacob Casey Yarick</b></font>

# %% [markdown]
# <div style="text-align:center; font-size:120px; line-height:1;">
# 🐊
# </div>
# <div style="text-align:center; font-size:45px; font-weight:bold; color:#0021A5;">
# University of Florida
# </div>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
#
# <details id="table-of-contents">
#
# <summary>
#   <h1 style="margin: 0; color: coral;">
#     Table of Contents
#   </h1>
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# Click any section below to jump directly to that part of the notebook.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
#
# <ul>
#
#   <li>
#     <a href="#notebook-overview"><b>Notebook Overview</b></a>
#     <ul>
#       <li><a href="#overview-workflow">Workflow Overview</a></li>
#       <li><a href="#overview-notes">Important Notes</a></li>
#     </ul>
#   </li>
#
#   <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
#
#   <li>
#     <a href="#project-files"><b>Project Files (Important)</b></a>
#   </li>
#
#   <hr style="border: none; height: 1px; background-color: #ddd; margin: 14px 0;">
#
#   <li>
#     <a href="#section-0"><b>Section 0 — Unpack Helpers (nanoHUB Setup)</b></a>
#   </li>
#
#   <li>
#     <a href="#section-1"><b>Section 1 — Setup & Community Definition</b></a>
#     <ul>
#       <li><a href="#section-1a">Section 1A — Import Libraries + Connect Helpers</a></li>
#       <li><a href="#section-1b">Section 1B — Power User Selection Editor</a></li>
#     </ul>
#   </li>
#
#   <li>
#     <a href="#section-2"><b>Section 2 — Energy Profile Visualization</b></a>
#   </li>
#
#   <li>
#     <a href="#section-3"><b>Section 3 — Transform Energy Profiles</b></a>
#     <ul>
#       <li><a href="#section-3a">Section 3A — Linear Calibration (Scale & Shift)</a></li>
#       <li><a href="#section-3b">Section 3B — Transformation Data Mathematically</a></li>
#     </ul>
#   </li>
#
#   <li>
#     <a href="#section-4"><b>Section 4 — Specify Building Counts</b></a>
#   </li>
#
#   <li>
#     <a href="#section-5"><b>Section 5 — Compute & Visualize Power Demand</b></a>
#   </li>
#
#   <li>
#     <a href="#section-6"><b>Section 6 — Export (Activity 4)</b></a>
#   </li>
#
#   <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
#
#   <li>
#     <a href="#future-improvements"><b>List of Future Improvements</b></a>
#   </li>
#
#   <li>
#     <a href="#appendix"><b>Appendix — Reference (Optional)</b></a>
#     <ul>
#       <li><a href="#appendix-a">Appendix A — Energy vs Power (15-Minute Data)</a></li>
#       <li><a href="#appendix-b">Appendix B — Linear Scale & Shift Mapping</a></li>
#       <li><a href="#appendix-c">Appendix C — Data Transformation Editor (What the Code Applies)</a></li>
#       <li><a href="#appendix-d">Appendix D — Power Computation & Aggregation</a></li>
#       <li><a href="#appendix-e">Appendix E — Output Files & Peak Table</a></li>
#       <li><a href="#appendix-f">Appendix F — Time Indexing, Windows, & Circular Shifts</a></li>
#       <li><a href="#appendix-g">Appendix G — Model Assumptions & Limits</a></li>
#       <li><a href="#appendix-h">Appendix H — Extending This Notebook Toward Machine Learning</a></li>
#     </ul>
#   </li>
#
# </ul>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
#
# <details id="notebook-overview">
#
# <summary>
#   <h1 style="margin: 0; color: coral;">
#     Notebook Overview
#   </h1>
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
# </summary>
#
# <p style="margin-top: 14px;">
# <b>Welcome to the PTCHS Activity 3 & 4 Notebook.</b>
# </p>
#
# <p>
# In this notebook, you will model <b>daily energy and power demand</b> for a small
# community by selecting representative building types, optionally modifying their
# energy profiles, and aggregating them into a <b>Total Grid</b> demand profile.
# </p>
#
# <p>
# This notebook is interactive. Some controls update live, but
# <b>plots, tables, and exported files update only when their cell is re-run</b>.
# </p>
#
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="overview-workflow">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Workflow Overview
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# You will work through the following sections <b>in order</b>.
# Each section below can be expanded for details.
# </p>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 0 — Project Files & Setup
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Verify required project files are present</li>
#   <li>Unpack the <code>helpers/</code> folder if needed</li>
#   <li>Configure imports so the notebook can run correctly</li>
#   <li>Confirm the environment is ready for the activity</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 1 — Setup & Community Definition
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Load and validate the energy dataset</li>
#   <li>Initialize internal application state</li>
#   <li>Select <b>exactly 10</b> building user types to represent a community</li>
#   <li>Rename, delete, or duplicate users as needed</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 2 — Energy Profile Visualization
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Visualize daily energy profiles (kWh)</li>
#   <li>Inspect cumulative daily energy consumption</li>
#   <li>Build intuition about timing and magnitude of energy use</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 3 — Transform Energy Profiles
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Optionally compute scale and shift using linear calibration</li>
#   <li>Modify profile magnitude, timing, smoothness, variability, and more</li>
#   <li>Preview changes before applying them</li>
#   <li>Apply transformations that persist downstream</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 4 — Building Counts Editor
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Assign a number of buildings to each user type</li>
#   <li>Confirm counts used for aggregation</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 5 — Compute & Visualize Power Demand
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Convert energy profiles into power demand (kW)</li>
#   <li>Aggregate users into a Total Grid profile</li>
#   <li>Generate plots, summary tables, and exported data</li>
# </ul>
#
# </details>
#
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
#
# <details>
# <summary>
#   <h3 style="margin: 0; color: #8C3F2B;">
#     Section 6 — Export (Activity 4)
#   </h3>
# <hr style="border: none; height: 2px; background-color: gray; margin: 10px 0;">
# </summary>
#
# <ul>
#   <li>Export all required Activity 4 files in one click</li>
#   <li>Save plots, the max-power table image, and the spreadsheet</li>
# </ul>
#
# </details>
#
# </details>
#
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="overview-notes">
#
# <summary>
#   <h2 style="margin: 0; color: gray;">
#     Important Notes
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <ul style="margin-top: 12px;">
#   <li>Work through the notebook <b>from top to bottom</b> the first time you use it.</li>
#   <li>Some controls update immediately, but <b>files are exported only when their button is clicked</b>.</li>
#   <li>There is typically no need to re-run earlier cells, as outputs refresh automatically.</li>
#   <li>If something behaves unexpectedly and does not resolve by continuing forward, <b>restart the kernel and run the notebook from top</b>.</li>
#   <li>You do not need to edit any code cells to complete this activity.</li>
#   <li>Exporting files multiple times may overwrite previous exports with the same name.</li>
# </ul>
#
# <p>
# Optional background explanations and mathematical details are provided
# in the <b>Appendix</b> at the end of the notebook.
# </p>
#
# </details>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
#
# <details id="project-files">
#
# <summary>
#   <h1 style="margin: 0; color: coral;">
#     Project Files (Important)
#   </h1>
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
# </summary>
#
# <p style="margin-top: 14px;">
# This notebook relies on a small helper package to keep the code clean and maintainable.
# </p>
#
# <p><b>Keep these items together in the same folder:</b></p>
#
# <ul>
#   <li><b>This notebook</b> (<code>.ipynb</code>)</li>
#   <li><b>all_users_energy.csv</b></li>
#   <li><b>helpers/</b> (folder)</li>
# </ul>
#
# <p>
# ⚠️ <font color="red"><b>Do not</b></font> rename the <b>helpers</b> folder,
# move individual files, or run the notebook from a different directory.
# </p>
#
# <p>
# If you move the notebook, move the <b>entire folder</b>, not just the
# <code>.ipynb</code> file.
# </p>
#
# </details>

# %% [markdown]
# <div style="display:flex; align-items:center; margin:25px 0;">
#   <div style="flex:1; height:2px; background:#222;"></div>
#   <div style="padding:0 12px; color:#C96A4A;">◆</div>
#   <div style="flex:1; height:2px; background:#222;"></div>
# </div>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-0">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 0 — Unpack Helpers (nanoHUB Setup)
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This section prepares the notebook environment and loads the data required for the
# rest of the activity.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What happens in Section 0:</b></p>
# <ul>
#   <li>Ensure required helper files are available and importable</li>
#   <li>Configure the Python environment for this notebook</li>
#   <li>Verify the presence of the energy dataset</li>
#   <li>Initialize the global application state used by all later sections</li>
# </ul>
#
# <p><b>Why this section matters:</b></p>
# <ul>
#   <li>All later sections depend on successful setup and initialization</li>
#   <li>Import errors or missing data almost always trace back to this step</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p>
# <font color="red"><b>Run order:</b></font><br>
# Run this section <b>once at the very beginning</b>, before any other sections.
# </p>
#
# <p>
# If later sections behave unexpectedly, restart the kernel and re-run
# <b>Section&nbsp;0</b> before continuing.
# </p>
#
# </details>

# %%
# --- nanoHUB Bootstrap (safe to rerun) ---
from pathlib import Path
import sys, zipfile, shutil

ROOT = Path.cwd()

ZIP_NAME = "helpers.zip"
HELPERS_DIR = ROOT / "helpers"
CSV_NAME = "all_users_energy.csv"   # just a presence check (loading happens in Section 1A)

# Disable IPython history DB (prevents readonly sqlite noise on nanoHUB)
try:
    from IPython import get_ipython
    ip = get_ipython()
    if ip is not None:
        ip.run_line_magic("config", "HistoryManager.enabled = False")
except Exception:
    pass

def setup_error(msg: str):
    raise RuntimeError(f"\n❌ Setup error: {msg}\n")

# 1) Ensure helpers/ exists (unzip if needed)
if not HELPERS_DIR.exists():
    zip_path = ROOT / ZIP_NAME
    if not zip_path.exists():
        setup_error(f"Missing {ZIP_NAME}. Upload {ZIP_NAME} next to this notebook.")
    try:
        with zipfile.ZipFile(zip_path, "r") as z:
            z.extractall(ROOT)
    except zipfile.BadZipFile:
        setup_error(f"{ZIP_NAME} is not a valid zip file. Re-upload a fresh copy.")

    # Validate unzip produced helpers/
    if not HELPERS_DIR.exists():
        # Common mistake: zip contains contents but not the helpers/ folder
        found = next((p for p in ROOT.rglob("helpers") if p.is_dir()), None)
        if found and found != HELPERS_DIR:
            shutil.move(str(found), str(HELPERS_DIR))
        if not HELPERS_DIR.exists():
            setup_error(
                f"Unzipped {ZIP_NAME} but did not find a top-level 'helpers/' folder. "
                f"Rebuild the zip with: zip -r helpers.zip helpers"
            )

# 2) Put project root on path (so `import helpers...` works)
root_str = str(ROOT)
if root_str not in sys.path:
    sys.path.insert(0, root_str)

# 3) Confirm required files are present (no loading here)
missing = []
if not (ROOT / CSV_NAME).exists():
    missing.append(CSV_NAME)

if missing:
    setup_error("Missing required file(s): " + ", ".join(missing) + ". Upload next to this notebook.")

print("✅ nanoHUB setup OK: helpers/ unpacked, imports ready, required files found.")

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-1">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 1 — Setup & Community Definition
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This section sets up the notebook and defines the <b>community</b>
# you will analyze for the rest of the activity.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What happens in Section 1:</b></p>
#
# <ul>
#   <li>Load and validate the energy dataset</li>
#   <li>Select <b>exactly 10</b> power users (building types) for your community</li>
# </ul>
#
# <p><b>Why this section matters:</b></p>
#
# <ul>
#   <li>Every plot, transformation, and grid calculation in later sections uses these 10 users</li>
#   <li>Your selections here become the starting point for the rest of the notebook</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p>
# <font color="red"><b>Run Order:</b></font><br>
# <b>1A → 1B</b> (Power User Selector)
# </p>
#
# <p>
# Do not skip cells, and avoid running later sections before
# Section&nbsp;1 is complete.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
#
# <details id="section-1a">
#
# <summary>
#   <h3 style="margin: 0; color: #3A78A6;">
#     Section 1A — Import Libraries + Connect Helpers
#   </h3>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# <b>Run this once at the start of the notebook.</b>
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What happens in Section 1A:</b></p>
#
# <ul>
#   <li>Import required Python libraries</li>
#   <li>Connect the notebook to the <code>helpers/</code> folder</li>
#   <li>Load <code>all_users_energy.csv</code></li>
#   <li>Initialize the application so interactive controls work later</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p>
# <font color="red"><b>⚠️ Common Fix (Import Error)</b></font><br>
# If you see <code>ModuleNotFoundError: No module named 'helpers'</code>:
# </p>
#
# <ul>
#   <li>Confirm <b>helpers/</b> is in the <b>same folder</b> as this notebook</li>
#   <li>Confirm <b>all_users_energy.csv</b> is also in that folder</li>
#   <li>Restart the notebook session and re-run <b>Section 1A</b></li>
# </ul>
#
# </details>

# %%
# Prevent IPython history sqlite noise on reruns (safe)
try:
    from IPython import get_ipython
    ip = get_ipython()
    if ip is not None:
        ip.run_line_magic("config", "HistoryManager.enabled = False")
except Exception:
    pass

# --- Project path setup ---
from helpers.env import ensure_project_root_on_path
ROOT = ensure_project_root_on_path()
print("✅ Setup OK")

# --- Data bundle ---
# NOTE: Time-range selection is intentionally fixed for this activity.
# Hooks for variable ranges may be added in a future version.
from helpers.data import load_energy_data_bundle
all_users, window, start_time, end_time, user_map = load_energy_data_bundle(
    data_path="all_users_energy.csv",
    start_time=6048,      # change as needed
    points_per_day=96
)
print("✅ Data loaded + user_map validated.")

# --- App state bootstrap (safe rerun) ---
from helpers.bootstrap import bootstrap_state
state, sync_state, bump_state = bootstrap_state(globals())

# Validate invariants immediately (catches bad state early)
sync_state(verbose=False)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
#
# <details id="section-1b">
#
# <summary>
#   <h3 style="margin: 0; color: #3A78A6;">
#     Section 1B — Power Users Selection Editor
#   </h3>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
# </summary>
#
# <p style="margin-top: 10px;">
# This cell opens the <b>Select Power Users</b> interface.
# </p>
#
# <p>
# <b>Your goal:</b> build a community with <b>exactly 10</b> power users.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
#
# <p><b>How to use the selector:</b></p>
#
# <ul>
#   <li><b>Search</b> to filter user types (optional).</li>
#   <li>Check one or more building types, then click <b>Add Power User</b>.</li>
#   <li>Under <b>Current Power Users</b>, you can:
#     <ul>
#       <li>Edit a name and click <b>Rename</b></li>
#       <li>Remove a user with <b>Delete</b></li>
#     </ul>
#   </li>
#   <li>Use <b>Check User Count</b> to confirm how many you currently have.</li>
#   <li>When you are done, you must have <b>10 total</b>.</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
#
# <p>
# <font color="red"><b>USAGE NOTE:</b></font><br>
# Later sections require <b>at least one</b> power user to be selected.
# This activity asks you to work with <b>exactly 10</b> users, but the notebook will still run with fewer or more.
# </p>
#
# </details>

# %%
from helpers.ui.sections import show_power_user_selector
show_power_user_selector(state, all_users, user_map, start_time, end_time, required_count=10)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-2">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 2 — Energy Profile Visualization
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This section displays the <b>daily energy behavior</b> of the power users you selected in Section&nbsp;1.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What you will see:</b></p>
#
# <ul>
#   <li><b>Daily energy profiles (kWh)</b> for each selected user</li>
#   <li><b>Cumulative daily energy</b>, showing how total energy builds over time</li>
# </ul>
#
# <p><b>How to interpret these plots:</b></p>
#
# <ul>
#   <li>The daily profile shows <b>when</b> energy is used throughout the day</li>
#   <li>The cumulative plot shows <b>how much total energy</b> has been used up to each time</li>
#   <li>Steeper segments in the cumulative curve indicate periods of higher energy use</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p>
# <font color="red"><b>USAGE NOTE:</b></font>
# </p>
#
# <ul>
#   <li>These plots show <b>energy (kWh)</b>, not power (kW)</li>
#   <li>The figures in this section are <b>for visualization only</b> and are not saved automatically</li>
# </ul>
#
# </details>

# %%
from helpers.ui.sections import show_energy_outputs
show_energy_outputs(state)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-3">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 3 — Transform Energy Profiles
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# In this section, you will adjust the <b>daily energy profiles</b> of individual power users
# to better represent realistic behavior.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What you can do in this section:</b></p>
#
# <ul>
#   <li>Compute scale and shift values using known energy ranges</li>
#   <li>Modify profile magnitude, timing, smoothness, and variability</li>
#   <li>Preview changes before committing them</li>
# </ul>
#
# <p>
# Each power user is edited <b>independently</b>, giving you fine control over how different
# building types behave.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font></p>
#
# <ul>
#   <li>Only changes that are <b>applied</b> affect later sections</li>
#   <li>Users are transformed <b>one at a time</b></li>
#   <li>All applied changes automatically carry forward</li>
# </ul>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
#
# <details id="section-3a">
#
# <summary>
#   <h3 style="margin: 0; color: #3A78A6;">
#     Section 3A — Linear Calibration (Scale & Shift)
#   </h3>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 10px 0;
# ">
# </summary>
#
# <p style="margin-top: 10px;">
# This tool computes <b>scale</b> and <b>shift</b> values that map one daily energy profile
# onto another using a <b>linear calibration</b>.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Concept</b></p>
#
# <p>
# You start with an existing energy profile <b>$E_0$</b> with full time-series data.
# </p>
#
# <p>
# You want to create a new profile <b>$E_1$</b> with a known daily energy range but
# no full time-series data.
# </p>
#
# <p>
# The assumption is that <b>$E_1$ has the same shape as $E_0$</b>,
# but spans a different minimum and maximum energy.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Model</b></p>
#
# <p>
# $$
# E_1(t) = a\,E_0(t) + b
# $$
# </p>
#
# <ul>
#   <li>$a$ — scale factor</li>
#   <li>$b$ — vertical shift</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What to enter</b></p>
#
# <ul>
#   <li>$E_{0,\min}, E_{0,\max}$ — min and max of the original profile</li>
#   <li>$E_{1,\min}, E_{1,\max}$ — estimated min and max of the new building type</li>
# </ul>
#
# <p>
# Click <b>Compute Scale + Shift</b> to calculate $a$ and $b$.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font><br>
# This step <b>does not modify data</b>. Parameters are applied in <b>Section&nbsp;3B</b>.
# </p>
#
# </details>

# %%
from helpers.ui.sections import show_scale_shift_calculator
show_scale_shift_calculator()

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-3b">
#
# <summary>
#   <h3 style="margin: 0; color: #3A78A6;">
#     Section 3B — Data Transformation Editor
#   </h3>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 10px;">
# Use this editor to modify the <b>daily energy profile</b> of each selected power user.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>How this editor works:</b></p>
#
# <ol>
#   <li>Select a user from the <b>User Type</b> field (you may type to search).</li>
#   <li>Adjust the math parameters to change the profile’s magnitude, timing, or shape.</li>
#   <li>
#     Use the buttons at the bottom to control how changes are handled:
#     <ul>
#       <li><b>Preview Changes</b> — update the plot only (nothing is saved).</li>
#       <li><b>Apply Changes</b> — commit the changes for this user.</li>
#       <li><b>Revert to Original</b> — discard applied changes and restore the baseline profile.</li>
#     </ul>
#   </li>
# </ol>
#
# <p>
# Each user is edited <b>independently</b>. You must repeat this process for every user
# you want to modify.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font></p>
#
# <ul>
#   <li><b>Preview</b> affects visualization only and does not persist.</li>
#   <li>Only <b>applied</b> changes affect later plots and calculations.</li>
#   <li>Noise can be made reproducible by enabling <b>Lock noise</b> before previewing or applying.</li>
#   <li>If a profile becomes unrealistic, use <b>Revert to Original</b> for that user.</li>
# </ul>
#
# </details>

# %%
from helpers.ui.sections import show_math_editor
show_math_editor(state)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-4">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 4 — Specify Building Counts
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# Choose <b>how many buildings</b> of each power user exist in your community.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What you will do:</b></p>
#
# <ul>
#   <li>Set a building count for each user</li>
#   <li>Click <b>Confirm Selection</b> to lock counts</li>
#   <li>(Optional) Reset all counts to 1</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font></p>
#
# <ul>
#   <li>Counts apply per <b>power user entry</b></li>
#   <li>Only <b>confirmed</b> counts are used</li>
#   <li>Counts directly scale Total Grid demand</li>
# </ul>
#
# </details>

# %%
from helpers.ui.sections import show_building_counts
show_building_counts(state, max_count=50)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-5">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 5 — Compute & Visualize Power Demand
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This section computes <b>power demand (kW)</b> for each user and the <b>Total Grid</b>.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What you will see:</b></p>
#
# <ul>
#   <li>Unscaled power plots (true magnitudes)</li>
#   <li>Scaled power plots (timing and shape)</li>
#   <li>Maximum power summary table</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>How to read the outputs:</b></p>
#
# <ul>
#   <li>Unscaled plots show true relative demand</li>
#   <li>Scaled plots highlight coincidence and timing</li>
#   <li>The table reports peak time and peak power</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font></p>
#
# <ul>
#   <li>Plots are <b>not saved automatically</b></li>
#   <li>Results depend on Sections 1, 3, and 4</li>
# </ul>
#
# </details>

# %%
from helpers.ui.sections import show_power_plots, show_power_outputs
show_power_plots(state, all_users, start_time, end_time, scaled_users=False)
show_power_plots(state, all_users, start_time, end_time, scaled_users=True)
show_power_outputs(state, all_users, start_time, end_time)

# %% [markdown]
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
#
# <details id="section-6">
#
# <summary>
#   <h2 style="margin: 0; color: royalblue;">
#     Section 6 — Export (Activity 4)
#   </h2>
# <hr style="
#   border: none;
#   height: 3px;
#   background: linear-gradient(to right, #222, #6FAF7A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# Export <b>all required Activity 4 files</b> in one click.
# </p>
#
# <p><b>What the export button does:</b></p>
#
# <ul>
#   <li>Saves plot images (<code>.png</code>)</li>
#   <li>Saves max power table image (<code>.png</code>)</li>
#   <li>Saves Activity 4 spreadsheet (<code>.xlsx</code>)</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><font color="red"><b>USAGE NOTE:</b></font></p>
#
# <ul>
#   <li>Export does <b>not</b> re-run earlier plots</li>
#   <li>Wait for <b>✅ Export complete</b> before proceeding</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p>
# <b>Click once</b> and wait for confirmation.
# </p>
#
# </details>

# %%
from helpers.ui.activity4 import show_activity4_export_button
show_activity4_export_button(state, all_users, start_time, end_time)

# %% [markdown]
# <div style="display:flex; align-items:center; margin:25px 0;">
#   <div style="flex:1; height:2px; background:#222;"></div>
#   <div style="padding:0 12px; color:#C96A4A;">◆</div>
#   <div style="flex:1; height:2px; background:#222;"></div>
# </div>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
#
# <details id="future-improvements">
#
# <summary>
#   <h1 style="margin: 0; color: coral;">
#     List of Future Improvements
#   </h1>
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
# </summary>
#
# <p style="margin-top: 14px;">
# Ideas below describe <b>optional future enhancements</b> that could make this notebook
# more robust, easier to reuse, and better suited for future classes.
# These are <b>not required</b> to complete the current activity.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Workflow robustness</b></p>
#
# <ul>
#   <li>
#     <font color="#C96A4A"><b>Pre-flight validation</b></font><br>
#     Before final outputs or export, automatically verify:
#     exactly <b>10 power users</b>, confirmed building counts,
#     valid time window, and no missing or negative energy values.
#   </li>
#
#   <li>
#     <font color="#C96A4A"><b>“Reset Everything” action</b></font><br>
#     A single button to restore the notebook to its initial state
#     (users, transformations, counts, and time window),
#     providing a clean restart without kernel resets.
#   </li>
#
#   <li>
#     <font color="#C96A4A"><b>Downstream consistency checks</b></font><br>
#     Light warnings if building counts or transformations are changed
#     after power outputs have already been generated.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Usability and scaling</b></p>
#
# <ul>
#   <li>
#     <font color="#C96A4A"><b>More robust time-window control</b></font><br>
#     The file tools already support changing the analysis time window;
#     future versions could further test and formalize this feature
#     so plots, summaries, and exports adapt reliably across
#     short windows (hours), daily slices, or longer periods.
#   </li>
#
#   <li>
#     <font color="#C96A4A"><b>Scenario naming and organization</b></font><br>
#     Allow students to assign a short scenario name
#     (e.g., “Urban weekday” or “Warehouse-heavy case”)
#     that propagates automatically to plot titles and exported filenames.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Model realism and reproducibility</b></p>
#
# <ul>
#   <li>
#     <font color="#C96A4A"><b>Optional aggregation realism</b></font><br>
#     Introduce controlled diversity across many buildings
#     (small timing offsets or noise variations)
#     to avoid perfectly synchronized demand when counts are large.
#   </li>
#
#   <li>
#     <font color="#C96A4A"><b>Scenario save / load</b></font><br>
#     Export and reload a lightweight snapshot (JSON)
#     capturing selected users, transformation parameters,
#     building counts, and time window for reproducibility.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Submission and assessment</b></p>
#
# <ul>
#   <li>
#     <font color="#C96A4A"><b>Submission bundle export</b></font><br>
#     Create a single, consistently named folder or zip containing
#     plots, the Excel file, and a short metadata summary
#     to simplify grading and resubmissions.
#   </li>
# </ul>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
#
# <details id="appendix">
#
# <summary>
#   <h1 style="margin: 0; color: coral;">
#     Appendix — Reference (Optional)
#   </h1>
# <hr style="
#   border: none;
#   height: 4px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 20px 0;
# ">
# </summary>
#
# <p style="margin-top: 14px;">
# This appendix contains optional reference material for understanding
# <b>units</b>, <b>transformation math</b>, and <b>how final outputs are computed</b>.
# </p>
#
# <p>
# It is <b>not required</b> to complete the activity.
# Use it if you want to understand what the model is doing under the hood,
# or if a result seems unexpected and you want to trace where it comes from.
# </p>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-a">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix A — Energy vs Power (15-Minute Data)
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# The dataset used in this notebook reports <code>*_kWh</code> values as
# <b>energy consumed over a fixed time interval</b>, not instantaneous power.
# Each entry corresponds to one 15-minute interval.
# </p>
#
# <p>
# This distinction matters because power is a <i>rate</i>, while energy is an
# <i>accumulated quantity</i>.
# To compare demand across users, apply transformations, and aggregate loads
# on a grid, the notebook works with
# <b>average power over each interval</b>.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Average power over a time interval</b></p>
#
# <p>Average power is defined as:</p>
#
# <p>
# $$
# \bar{P} = \frac{E}{\Delta t}
# $$
# </p>
#
# <p>
# In this notebook, the timestep is fixed:
# </p>
#
# <p>
# $$
# \Delta t = 15\ \text{minutes} = 0.25\ \text{hours}
# $$
# </p>
#
# <p>
# Substituting gives:
# </p>
#
# <p>
# $$
# \bar{P}(\text{kW}) = \frac{E(\text{kWh})}{0.25} = 4E
# $$
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Why this conversion is safe here</b></p>
#
# <p>
# Because the timestep is constant across the dataset, converting between
# interval energy (kWh) and average power (kW) is a simple rescaling and
# <b>does not discard information</b>.
# This allows the notebook to store data in <b>energy form</b>
# while performing analysis in <b>power form</b>,
# without changing the underlying time resolution.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-b">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix B — Linear Scale & Shift Mapping
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# Linear calibration is used when you want to create a new energy profile
# <b>$E_1(t)$</b> from an existing profile <b>$E_0(t)$</b>,
# but with a different minimum and maximum daily energy.
# </p>
#
# <p>
# This situation arises when you:
# </p>
#
# <ul>
#   <li>have <b>full time-series data</b> for one building type, and</li>
#   <li>only know the <b>expected energy range</b> for another building type.</li>
# </ul>
#
# <p>
# The assumption is that the two profiles share the same <b>shape</b>,
# but differ in <b>scale</b> and <b>baseline</b>.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Linear model</b></p>
#
# <p>
# The mapping is assumed to be linear:
# </p>
#
# <p>
# $$
# E_1(t) = a\,E_0(t) + b
# $$
# </p>
#
# <p>
# where $a$ controls overall magnitude and $b$ shifts the profile vertically.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Solving for $a$ and $b$</b></p>
#
# <p>
# Let:
# </p>
#
# <ul>
#   <li>$E_{0,\min}, E_{0,\max}$ be the minimum and maximum of the original profile</li>
#   <li>$E_{1,\min}, E_{1,\max}$ be the desired minimum and maximum of the new profile</li>
# </ul>
#
# <p>
# We require the mapping to satisfy:
# </p>
#
# <p>
# $$
# \begin{aligned}
# a\,E_{0,\min} + b &= E_{1,\min} \\
# a\,E_{0,\max} + b &= E_{1,\max}
# \end{aligned}
# $$
# </p>
#
# <p>
# Subtracting the first equation from the second gives:
# </p>
#
# <p>
# $$
# a = \frac{E_{1,\max} - E_{1,\min}}{E_{0,\max} - E_{0,\min}}
# $$
# </p>
#
# <p>
# Substituting back yields:
# </p>
#
# <p>
# $$
# b = E_{1,\min} - a\,E_{0,\min}
# $$
# </p>
#
# <p>
# These two values uniquely define the linear calibration from $E_0$ to $E_1$.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What this does — and does not — change</b></p>
#
# <ul>
#   <li>This calibration preserves the <b>relative shape</b> of the profile.</li>
#   <li>Only the <b>range</b> (minimum and maximum) is modified.</li>
#   <li>No smoothing, shifting, or randomness is applied at this stage.</li>
# </ul>
#
# <p>
# In the notebook workflow, this step computes <b>parameters only</b>.
# The actual profile modification occurs later in the
# <b>Data Transformation Editor</b>.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-c">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix C — Data Transformation Editor (What the Code Applies)
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# The Data Transformation Editor operates on a single user’s
# <b>daily energy profile</b> as a <b>sequential transformation pipeline</b>.
# Each step consumes the output of the previous step and produces a new
# energy array.
# </p>
#
# <p>
# This design is intentional: once a transformation is applied, the editor
# treats the result as the new baseline for that user.
# For this reason, the editor separates <b>previewing</b> transformations from
# <b>committing</b> them.
# </p>
#
# <p>
# Let the original daily energy profile be:
# </p>
#
# <p>
# $$
# E_0(t)
# $$
# </p>
#
# <p>
# Each subsequent operation produces a new profile
# $E_k(t)$ according to the equations below.
# The order shown here matches the implementation and must be preserved.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Sequential transformation pipeline</b></p>
#
# <p>
# Each transformation operates on the output of the previous step.
# This ordering is intentional: earlier steps set the large-scale structure,
# while later steps add realism without altering that structure.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <ol>
#   <li>
#     <b>Scale + Shift</b><br>
#     Adjust overall magnitude and baseline:
#     <p>
#     $$
#     E_1(t) = a\,E_0(t) + b
#     $$
#     </p>
#     <p>
#     This step rescales the profile while preserving its shape.
#     The values of $a$ and $b$ may be computed using linear calibration
#     or chosen directly for exploratory modeling.
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Noise / Jitter (optional)</b><br>
#     Introduce stochastic variability proportional to the signal:
#     <p>
#     $$
#     E_2(t) = E_1(t) + \varepsilon(t)
#     $$
#     </p>
#     <p>
#     where $\varepsilon(t)$ is a random perturbation drawn independently
#     at each timestep.
#     This step exists to model real-world variability and to prevent
#     unrealistically identical load shapes.
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Deviation (contrast control)</b><br>
#     Adjust peak–valley contrast about the daily mean:
#     <p>
#     $$
#     E_3(t) = \mu + f\,[E_2(t) - \mu]
#     $$
#     </p>
#     <p>
#     where $\mu$ is the mean of $E_2(t)$.
#     This rescales both structure and variability relative to the mean.
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Hourly time weights</b><br>
#     Apply hour-specific multipliers:
#     <p>
#     $$
#     E_4(t) = w_h\,E_3(t)
#     $$
#     </p>
#     <p>
#     where $w_h$ is the weight for the hour containing timestep $t$
#     (each hour spans four 15-minute bins).
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Smoothing (optional)</b><br>
#     Reduce high-frequency variation via Gaussian smoothing:
#     <p>
#     $$
#     E_5(t) = \mathcal{G}\!\left[E_4(t)\right]
#     $$
#     </p>
#     <p>
#     This step represents physical inertia or aggregated behavior over time
#     and is applied only if SciPy is available.
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Time shift</b><br>
#     Circularly shift the profile by an integer number of 15-minute intervals:
#     <p>
#     $$
#     E_6(t) = E_5(t - \Delta t_{\text{shift}})
#     $$
#     </p>
#   </li>
#
#   <hr style="border: none; height: 0.5px; background-color: gray; margin: 2px 0;">
#
#   <li>
#     <b>Final clipping (physical validity)</b><br>
#     Enforce non-negative energy values after all transformations:
#     <p>
#     $$
#     E_7(t) = \max\!\left(E_6(t),\,0\right)
#     $$
#     </p>
#     <p>
#     This step exists solely to ensure physical validity.
#     It does not change the intended profile shape.
#     </p>
#   </li>
# </ol>
# <hr style="border: none; height: 1px; background-color: gray; margin: 10px 0;">
# <p>
# The final transformed profile is $E_7(t)$.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Noise, seeding, and reproducibility</b></p>
#
# <p>
# Noise is the only <b>stochastic</b> step in the pipeline.
# Because it changes numerical outcomes, the editor explicitly separates
# <b>variability</b> from <b>reproducibility</b>.
# </p>
#
# <ul>
#   <li>
#     When <b>Lock Noise (Reproducible)</b> is enabled, a fixed random seed is used.
#     Applying the same parameters produces the same noise realization
#     and therefore the same downstream profiles.
#   </li>
#
#   <li>
#     When noise is <b>not locked</b>, a new random realization is generated
#     each time Apply is clicked.
#     In this mode, the seed value is intentionally ignored.
#   </li>
# </ul>
#
# <p>
# Randomness should only be “frozen” <b>after</b> a student decides
# a specific scenario should be preserved.
# Before that point, changing noise realizations is expected behavior.
# </p>
#
# <p>
# Locking noise supports:
# </p>
#
# <ul>
#   <li><b>Controlled experiments</b> and fair grading</li>
#   <li><b>Reproducibility</b> across exports and saved results</li>
# </ul>
#
# <p>
# Unlocked noise supports:
# </p>
#
# <ul>
#   <li><b>Exploration</b> of stochastic behavior</li>
#   <li><b>Realistic diversity</b> between otherwise similar users</li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Preview vs Apply</b></p>
#
# <p>
# <b>Preview</b> computes the full transformation pipeline
# $E_0 \rightarrow E_7$ without modifying stored state.
# <b>Apply</b> commits the final profile and replaces the user’s active dataset.
# </p>
#
# <p>
# Because the pipeline is sequential and may include randomness,
# this separation prevents accidental drift and ensures that
# committed results are intentional.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-d">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix D — Power Computation & Aggregation
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# Power is computed <b>only after all energy transformations are finalized</b>,
# using the final per-building energy profiles and the specified number of buildings
# for each user type.
# </p>
#
# <p>
# This separation is intentional: transformations modify the
# <b>shape</b> of a single building’s daily energy profile,
# while aggregation controls overall <b>scale</b> through building counts.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Per-user power computation</b></p>
#
# <p>
# For a single user type, average power at each timestep is computed as:
# </p>
#
# <p>
# $$
# \bar{P}_{\text{user}}(t)
# = 4\,E_{\text{user}}(t)\times N_{\text{buildings}}
# $$
# </p>
#
# <p>
# where:
# </p>
#
# <ul>
#   <li>$E_{\text{user}}(t)$ is the final transformed <b>per-building</b> energy profile,</li>
#   <li>$N_{\text{buildings}}$ is the confirmed building count, and</li>
#   <li>the factor of 4 converts 15-minute interval energy (kWh)
#       to average power (kW).</li>
# </ul>
#
# <p>
# This calculation is performed independently at each 15-minute timestep.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Total Grid aggregation</b></p>
#
# <p>
# The <b>Total Grid</b> power profile is computed as the sum across all selected users:
# </p>
#
# <p>
# $$
# \bar{P}_{\text{Total}}(t) = \sum_i \bar{P}_i(t)
# $$
# </p>
#
# <p>
# Aggregation affects only the <b>magnitude</b> of demand.
# No reshaping, smoothing, or timing adjustments occur at this stage;
# all temporal structure is inherited directly from the transformed
# energy profiles.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-e">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix E — Output Files & Peak Table
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;"><b>Saved artifacts</b></p>
#
# <p>
# The notebook exports multiple outputs, each serving a distinct analytical purpose.
# Together, they capture both <b>energy usage</b> and <b>power demand</b>
# at the individual user and Total Grid levels.
# </p>
#
# <ul>
#   <li>
#     <b>Energy profile plots</b> (<code>.png</code>) —
#     per-user daily energy profiles after all transformations,
#     shown as energy per interval.
#     These plots emphasize <b>usage shape</b> independent of aggregation.
#   </li>
#
#   <li>
#     <b>Cumulative energy plots</b> (<code>.png</code>) —
#     time-integrated energy consumption over the day.
#     These plots emphasize <b>total energy use</b> rather than instantaneous demand.
#   </li>
#
#   <li>
#     <b>Unscaled power plots</b> (<code>.png</code>) —
#     each user is shown on its own vertical scale.
#     These plots emphasize <b>shape, timing, and coincidence</b> of demand.
#   </li>
#
#   <li>
#     <b>Scaled power plots</b> (<code>.png</code>) —
#     all users share a common vertical scale.
#     These plots emphasize <b>relative magnitude</b> across users.
#   </li>
#
#   <li>
#     <b>Maximum power summary table</b> (<code>.png</code>) —
#     reports each user’s peak demand and its contribution
#     relative to the Total Grid peak.
#   </li>
#
#   <li>
#     <b>Power data spreadsheet</b> (<code>.xlsx</code>) —
#     time-resolved power values for all users and the Total Grid,
#     used directly for Activity&nbsp;4 analysis.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Peak percentage interpretation</b></p>
#
# <p>
# The percentage column answers the question:
# </p>
#
# <p>
# <i>
# How does this user's peak demand compare to the grid's peak demand?
# </i>
# </p>
#
# <p>
# Formally:
# </p>
#
# <p>
# $$
# \text{Percent of Total Grid Peak}
# =
# 100 \times
# \frac{P_{\max,\ \text{user}}}
#      {P_{\max,\ \text{Total Grid}}}
# $$
# </p>
#
# <p>
# where $P_{\max,\ \text{Total Grid}}$ is the grid’s peak demand
# at the single timestep when the Total Grid reaches its maximum.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Conceptual understanding</b></p>
#
# <p>
# These percentages generally <b>do not sum to 100%</b>.
# This is expected behavior.
# </p>
#
# <p>
# Individual users typically reach their peak demand at
# <b>different times</b> than the grid’s peak.
# The percentages shown compare each user’s
# <b>own maximum demand</b> to the
# <b>maximum demand of the total grid</b>,
# even though those peaks may occur at different times.
# </p>
#
# <p>
# In the special case where all users peak at the same time,
# the percentages would sum to 100%.
# </p>
#
# <p>
# In practice, the sum of percentages can approach 100% when one or more
# <b>dominant user types</b> are present.
# A user may be dominant because:
# </p>
#
# <ul>
#   <li>it has a very large per-building demand, or</li>
#   <li>it exists in large numbers, causing moderate individual demand
#       to aggregate into a large grid contribution.</li>
# </ul>
#
# <p>
# Importantly, percentages are <b>not</b> normalized against the sum of all
# users’ individual peak values.
# They are normalized against the
# <b>maximum demand ever reached by the Total Grid</b>,
# even though individual users may peak at different times.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-f">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix F — Time Indexing, Windows, & Circular Shifts
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This appendix explains how <b>time indexing</b>, <b>time windows</b>,
# and <b>circular shifts</b> work in this notebook.
# </p>
#
# <p>
# These details are not required to complete the activity,
# but they are useful if you want to understand
# <b>why profiles move the way they do</b>
# and how timing affects aggregation.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Fixed timestep</b></p>
#
# <p>
# All data in this notebook uses a <b>fixed 15-minute timestep</b>.
# Each day is divided into:
# </p>
#
# <p>
# $$
# 96 \text{ timesteps per day}
# $$
# </p>
#
# <p>
# Time is therefore indexed as:
# </p>
#
# <p>
# $$
# t = 0, 1, 2, \dots, 95
# $$
# </p>
#
# <p>
# Each index corresponds to a specific 15-minute interval,
# not a continuously varying clock time.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Time windows</b></p>
#
# <p>
# The notebook allows analysis over a selected <b>time window</b>,
# which may represent:
# </p>
#
# <ul>
#   <li>a single day,</li>
#   <li>a partial day, or</li>
#   <li>a longer continuous slice of data.</li>
# </ul>
#
# <p>
# Changing the time window affects:
# </p>
#
# <ul>
#   <li>which timesteps are plotted,</li>
#   <li>which timesteps are exported, and</li>
#   <li>where peaks may appear.</li>
# </ul>
#
# <p>
# It does <b>not</b> change the meaning of individual timesteps,
# the energy-to-power conversion,
# or the transformation math.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Circular time shifts</b></p>
#
# <p>
# When a time shift is applied in the Data Transformation Editor,
# the profile is shifted <b>circularly</b>.
# </p>
#
# <p>
# This means values shifted past the end of the day
# wrap around to the beginning.
# </p>
#
# <p>
# Mathematically:
# </p>
#
# <p>
# $$
# E(t) \;\rightarrow\; E(t - \Delta t_{\text{shift}})
# $$
# </p>
#
# <p>
# with indexing performed modulo 96.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Physical interpretation</b></p>
#
# <p>
# A circular shift represents a <b>change in timing</b>,
# not a change in total energy.
# </p>
#
# <ul>
#   <li>Total daily energy is preserved.</li>
#   <li>Peak timing may move earlier or later.</li>
#   <li>Relative alignment between users may change.</li>
# </ul>
#
# <p>
# This is intentional: shifting allows students to explore
# how <b>coincidence of demand</b> affects grid-level peaks
# without altering per-building usage.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Shifts and aggregation</b></p>
#
# <p>
# When multiple users are aggregated:
# </p>
#
# <ul>
#   <li>shifting a single user can <b>increase</b> or <b>decrease</b>
#       the Total Grid peak,</li>
#   <li>even if that user’s total energy remains unchanged.</li>
# </ul>
#
# <p>
# This occurs because grid peaks depend on
# <b>simultaneous demand</b>, not individual maxima.
# </p>
#
# <p>
# Time shifts therefore affect <b>when</b> demand occurs,
# not <b>how much</b> energy is used.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Why circular shifts are used</b></p>
#
# <p>
# Circular shifting avoids edge effects that would otherwise:
# </p>
#
# <ul>
#   <li>introduce artificial zeros,</li>
#   <li>truncate demand near the boundaries, or</li>
#   <li>change total energy.</li>
# </ul>
#
# <p>
# This makes timing experiments cleaner and easier to interpret,
# especially when comparing multiple users.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Summary</b></p>
#
# <ul>
#   <li>Time is discretized into fixed 15-minute intervals.</li>
#   <li>Time windows select which intervals are analyzed.</li>
#   <li>Time shifts move demand <b>without</b> changing total energy.</li>
#   <li>Circular wrap-around preserves physical consistency.</li>
# </ul>
#
# <p>
# These design choices allow timing effects to be explored
# independently from energy magnitude.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-g">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix G — Model Assumptions & Limits
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This appendix summarizes the <b>assumptions</b> built into the model
# and the <b>limits</b> of the conclusions that can be drawn from it.
# </p>
#
# <p>
# The goal is not to list flaws, but to clarify
# <b>what the model is designed to represent</b>
# and what is intentionally left out.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Core assumptions</b></p>
#
# <ul>
#   <li>
#     Each building type is represented by a
#     <b>typical daily energy profile</b>.
#   </li>
#
#   <li>
#     That profile is assumed to repeat for the selected time window
#     unless explicitly modified.
#   </li>
#
#   <li>
#     All buildings of the same user type share the same
#     underlying profile shape.
#   </li>
#
#   <li>
#     Energy use within each 15-minute interval is treated
#     as uniformly distributed over that interval.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Aggregation assumptions</b></p>
#
# <ul>
#   <li>
#     Total Grid demand is computed as a
#     <b>simple sum</b> of individual user demands.
#   </li>
#
#   <li>
#     There are no feedback effects between users
#     (one user’s behavior does not alter another’s).
#   </li>
#
#   <li>
#     Building counts scale demand linearly.
#   </li>
# </ul>
#
# <p>
# These assumptions isolate the effects of
# <b>profile shape</b>, <b>timing</b>, and <b>count</b>
# without introducing additional system complexity.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What this model does not include</b></p>
#
# <ul>
#   <li>Weather variation or seasonal effects</li>
#   <li>Day-to-day behavioral changes</li>
#   <li>Demand response or load shedding</li>
#   <li>Physical grid constraints (lines, transformers, losses)</li>
#   <li>Electricity pricing or operational cost</li>
# </ul>
#
# <p>
# As a result, the model should be interpreted as a
# <b>demand-shape exploration tool</b>,
# not a full power system simulator.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>How to interpret results</b></p>
#
# <ul>
#   <li>
#     Changes in <b>peak power</b> reflect timing and coincidence effects,
#     not infrastructure limits.
#   </li>
#
#   <li>
#     Changes in <b>total energy</b> reflect scaling and profile magnitude,
#     not efficiency improvements.
#   </li>
#
#   <li>
#     Two scenarios with the same total energy
#     can produce very different peak demands.
#   </li>
# </ul>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Appropriate conclusions</b></p>
#
# <ul>
#   <li>
#     Which building types tend to drive grid peaks
#   </li>
#
#   <li>
#     How timing alignment affects Total Grid demand
#   </li>
#
#   <li>
#     How scaling certain users changes peak stress
#   </li>
# </ul>
#
# <p>
# These insights are sufficient for comparing scenarios
# and understanding tradeoffs in community-level demand.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Summary</b></p>
#
# <ul>
#   <li>This notebook models <b>demand behavior</b>, not grid physics.</li>
#   <li>Assumptions are intentional and simplify interpretation.</li>
#   <li>Results should be used for <b>comparison</b>, not prediction.</li>
# </ul>
#
# <p>
# Understanding these limits helps ensure that conclusions
# drawn from the model are accurate and appropriate.
# </p>
#
# </details>

# %% [markdown]
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
#
# <details id="appendix-h">
#
# <summary>
#   <h2 style="margin: 0; color: #C96A4A;">
#     Appendix H — Extending This Notebook Toward Machine Learning
#   </h2>
# <hr style="
#   border: none;
#   height: 2px;
#   background: linear-gradient(to right, #222, #C96A4A, #222);
#   margin: 15px 0;
# ">
# </summary>
#
# <p style="margin-top: 12px;">
# This appendix outlines how the ideas in this notebook
# could be extended toward <b>machine learning (ML)</b>.
# </p>
#
# <p>
# ML is <b>not required</b> for this activity.
# This section is included for students who are curious about
# how modeling, simulation, and data-driven methods connect.
# </p>
#
# <p>⚠️ Machine learning is introduced here not to replace physical calculations, but to approximate and invert them when the design space becomes too large to explore directly.</p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What this notebook already provides</b></p>
#
# <p>
# By the time you reach the end of this activity, you have already built:
# </p>
#
# <ul>
#   <li>clean, aligned <b>time-series data</b>,</li>
#   <li>controlled <b>scenario variations</b>, and</li>
#   <li>clear <b>numerical outcomes</b> (peaks, timing, contributions).</li>
# </ul>
#
# <p>
# This is exactly the kind of structured, labeled data
# that machine learning models require.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Compare vs predict</b></p>
#
# <p>
# The goal of extending this notebook toward ML would be to
# <b>compare scenarios</b>, not to predict the real future.
# </p>
#
# <p>
# For example:
# </p>
#
# <ul>
#   <li>Which scenario produces a higher grid peak?</li>
#   <li>Which user types most strongly influence peak demand?</li>
#   <li>How does timing matter relative to magnitude?</li>
# </ul>
#
# <p>
# This differs from prediction, which would attempt to forecast
# actual future demand using real-world data.
# </p>
#
# <p>
# The notebook is intentionally designed for comparison and exploration,
# not for real-time forecasting.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Learning from scenarios (supervised learning)</b></p>
#
# <p>
# A natural first ML step would be to generate many valid scenarios
# using this notebook and train a model to learn relationships between:
# </p>
#
# <ul>
#   <li><b>Inputs</b>: user counts, transformation parameters, time shifts</li>
#   <li><b>Outputs</b>: grid peak power, peak timing, user contributions</li>
# </ul>
#
# <p>
# The model would not predict the future.
# It would learn how different design choices
# <b>compare</b> to one another.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>What the model would learn</b></p>
#
# <ul>
#   <li>Which parameters most strongly drive peak demand</li>
#   <li>Nonlinear interactions between users</li>
#   <li>How synchronization affects grid stress</li>
# </ul>
#
# <p>
# This turns the notebook into a <b>data generator</b>
# and the ML model into a fast <b>surrogate</b>
# for exploring many scenarios.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Learning demand shapes (advanced)</b></p>
#
# <p>
# Instead of predicting a single value like peak power,
# an ML model could be trained to predict the
# <b>entire grid power curve</b>.
# </p>
#
# <p>
# In this case:
# </p>
#
# <ul>
#   <li>Inputs describe the scenario setup</li>
#   <li>Outputs are the full time-series demand profile</li>
# </ul>
#
# <p>
# This approach focuses on timing, coincidence, and shape,
# not just magnitude.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Inverse design</b></p>
#
# <p>
# An advanced extension is to reverse the problem:
# </p>
#
# <p>
# <i>
# “What changes would reduce the grid peak by a desired amount?”
# </i>
# </p>
#
# <p>
# This involves:
# </p>
#
# <ul>
#   <li>a trained model that estimates grid response, and</li>
#   <li>an optimization step that searches for better scenarios.</li>
# </ul>
#
# <p>
# This mirrors how ML is used in real engineering design,
# not as a prediction tool, but as a guide for decision-making.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Toward real-world forecasting (optional)</b></p>
#
# <p>
# The machine learning approaches described above
# learn relationships within this notebook’s model.
# They do <b>not</b> predict real future demand.
# </p>
#
# <p><b><font color="purple">Question:</font> What data would be needed for real forecasting?</b></p>
#
# <p>
# To predict future demand (instead of comparing scenarios),
# an ML model needs <b>historical ground-truth data</b>
# and variables that drive demand.
# </p>
#
# <ul>
#   <li><b>Historical demand</b>: measured power (kW) or energy (kWh) over many days</li>
#   <li><b>Weather</b>: temperature (most important), humidity, extreme events</li>
#   <li><b>Calendar</b>: weekday/weekend, holidays, school schedules</li>
#   <li><b>Community context</b>: population changes, special events, outages (if available)</li>
# </ul>
#
# <p>
# With those inputs, forecasting becomes a problem of learning
# patterns in real data — not just learning behavior inside a simulator.
# </p>
#
# <p>
# This distinction is intentional:
# learning how design choices affect demand
# is a necessary step <b>before</b> attempting prediction.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b><font color="purple">Question:</font> How would you judge a forecast?</b></p>
#
# <p>
# A forecast is only useful if it performs well on data it has never seen.
# This is tested by training on earlier days and evaluating on later days.
# </p>
#
# <ul>
#   <li><b>MAE</b>: average absolute error (typical “how far off”)</li>
#   <li><b>Peak error</b>: how accurate the model is on the highest-demand periods</li>
#   <li><b>Timing error</b>: how close the predicted peak time is to the real peak time</li>
# </ul>
#
# <p>
# In power systems, getting peak magnitude and peak timing right
# often matters more than being perfect everywhere.
# </p>
#
# <hr style="border: none; height: 1px; background-color: gray; margin: 5px 0;">
#
# <p><b>Summary</b></p>
#
# <ul>
#   <li>This notebook already generates <b>ML-ready, structured data</b>.</li>
#   <li>Machine learning can be used to <b>compare scenarios</b>
#       and understand how design choices affect demand.</li>
#   <li>Predicting real future demand would require
#       <b>additional real-world data</b>
#       and is intentionally out of scope here.</li>
# </ul>
#
# <p>
# Seen this way, the notebook is both a
# <b>learning tool</b> and a <b>foundation</b>
# for more advanced modeling.
# </p>
#
# </details>

# %% [markdown]
# # <font color="#1E7F3F">END OF NOTEBOOK</font>
#
# <div style="margin:25px 0; border-radius:6px; overflow:hidden;">
#   <div style="height:10px; background:linear-gradient(to right,
#     #D64541,
#     #F39C12,
#     #F1C40F,
#     #27AE60,
#     #16A085,
#     #2980B9,
#     #8E44AD
#   );"></div>
# </div>
